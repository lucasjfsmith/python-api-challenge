# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
northern_hemi_df['Lat'].name
# Out:
# 'Lat'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + f"&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | sao filipe
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | pochutla
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | cardston
# Processing Record 9 of Set 1 | lerwick
# Processing Record 10 of Set 1 | awjilah
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | nemuro
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | selikhino
# Processing Record 15 of Set 1 | beruwala
# Processing Record 16 of Set 1 | roebourne
# Processing Record 17 of Set 1 | guilin
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | namtsy
# Processing Record 20 of Set 1 | goderich
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | kibaya
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | husavik
# Processing Record 25 of Set 1 | enshi
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | benjamin constant
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | gilleleje
# Processing Record 31 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 1 | itoman
# Processing Record 33 of Set 1 | pirenopolis
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | asau
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | poso
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | najran
# Processing Record 43 of Set 1 | sal rei
# Processing Record 44 of Set 1 | bowen
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | mobaye
# Processing Record 0 of Set 2 | punta arenas
# Processing Record 1 of Set 2 | backa topola
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | matara
# Processing Record 4 of Set 2 | diamantino
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | oudtshoorn
# Processing Record 11 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 2 | mount gambier
# Processing Record 13 of Set 2 | gat
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | port macquarie
# Processing Record 18 of Set 2 | asyut
# Processing Record 19 of Set 2 | mount isa
# Processing Record 20 of Set 2 | la teste-de-buch
# Processing Record 21 of Set 2 | derbent
# Processing Record 22 of Set 2 | pulaski
# Processing Record 23 of Set 2 | riacho de santana
# Processing Record 24 of Set 2 | belaya gora
# Processing Record 25 of Set 2 | santa isabel do rio negro
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | poronaysk
# Processing Record 28 of Set 2 | grindavik
# Processing Record 29 of Set 2 | dingle
# Processing Record 30 of Set 2 | jinchang
# Processing Record 31 of Set 2 | qasigiannguit
# Processing Record 32 of Set 2 | cherskiy
# Processing Record 33 of Set 2 | san andres
# Processing Record 34 of Set 2 | mehamn
# Processing Record 35 of Set 2 | broome
# Processing Record 36 of Set 2 | albany
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | araouane
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | antigonish
# Processing Record 42 of Set 2 | rorvik
# Processing Record 43 of Set 2 | tabukiniberu
# City not found. Skipping...
# Processing Record 44 of Set 2 | bonavista
# Processing Record 45 of Set 2 | andenes
# Processing Record 46 of Set 2 | mecca
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 2 | dongsheng
# Processing Record 0 of Set 3 | artyk
# City not found. Skipping...
# Processing Record
of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | aracatuba
# Processing Record 40 of Set 4 | jijiga
# Processing Record 41 of Set 4 | nardaran
# Processing Record 42 of Set 4 | kazanka
# Processing Record 43 of Set 4 | saint-gaudens
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | clyde river
# Processing Record 47 of Set 4 | san carlos de bariloche
# Processing Record 48 of Set 4 | pinawa
# Processing Record 49 of Set 4 | norman wells
# Processing Record 0 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 1 of Set 5 | ahipara
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | alcaniz
# Processing Record 4 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | haines junction
# Processing Record 7 of Set 5 | lagoa
# Processing Record 8 of Set 5 | ola
# Processing Record 9 of Set 5 | ust-ilimsk
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | cassilandia
# Processing Record 12 of Set 5 | ugoofaaru
# Processing Record 13 of Set 5 | luanda
# Processing Record 14 of Set 5 | kasamwa
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | dargaville
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | farah
# Processing Record 20 of Set 5 | arosa
# Processing Record 21 of Set 5 | leningradskiy
# Processing Record 22 of Set 5 | hwange
# Processing Record 23 of Set 5 | havre-saint-pierre
# Processing Record 24 of Set 5 | zhigansk
# Processing Record 25 of Set 5 | cairns
# Processing Record 26 of Set 5 | beloha
# Processing Record 27 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 28 of Set 5 | castro
# Processing Record 29 of Set 5 | morgaushi
# Processing Record 30 of Set 5 | ouidah
# Processing Record 31 of Set 5 | mountain home
# Processing Record 32 of Set 5 | yumen
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | surt
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | vao
# Processing Record 37 of Set 5 | kismayo
# Processing Record 38 of Set 5 | lavrentiya
# Processing Record 39 of Set 5 | calabozo
# Processing Record 40 of Set 5 | whitley bay
# Processing Record 41 of Set 5 | sola
# Processing Record 42 of Set 5 | rubiataba
# Processing Record 43 of Set 5 | bilma
# Processing Record 44 of Set 5 | manavalakurichi
# Processing Record 45 of Set 5 | paraopeba
# Processing Record 46 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 5 | comodoro rivadavia
# Processing Record 48 of Set 5 | saint-pierre
# Processing Record 49 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 0 of Set 6 | sao joao da barra
# Processing Record 1 of Set 6 | mayo
# Processing Record 2 of Set 6 | thunder bay
# Processing Record 3 of Set 6 | kavieng
# Processing Record 4 of Set 6 | mahebourg
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | codrington
# Processing Record 7 of Set 6 | aksha
# Processing Record 8 of Set 6 | severo-kurilsk
# Processing Record 9 of Set 6 | saint-joseph
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | caramoran
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | coracora
# Processing Record 14 of Set 6 | xiongyue
# Processing Record 15 of Set 6 | dalnerechensk
# Processing Record 16 of Set 6 | curup
# Processing Record 17 of Set 6 | satis
# Processing Record 18 of Set 6 | alice springs
# Processing Record 19 of Set 6 | aksu
# Processing Record 20 of Set 6 | lookan
# Processing Record 21 of Set 6 | ambon
# Processing Record 22 of Set 6 | kyakhta
# Processing Record 23 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 25 of Set 6 | pachino
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | ancud
# Processing Record 28 of Set 6 | zhezkazgan
# Processing Record 29 of Set 6 | batagay-alyta
# Processing Record 30 of Set 6 | mansa
# Processing Record 31 of Set 6 | amarillo
# Processing Record 32 of Set 6 | saint-philippe
# Processing Record 33 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | fort nelson
# Processing Record 35 of Set 6 | kieta
# Processing Record 36 of Set 6 | maymanak
# City not found. Skipping...
# Processing Record 37 of Set 6 | sedkyrkeshch
# Processing Record 38 of Set 6 | tacoronte
# Processing Record 39 of Set 6 | tual
# Processing Record 40 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 6 | ponta do sol
# Processing Record 42 of Set 6 | bay roberts
# Processing Record 43 of Set 6 | lasa
# Processing Record 44 of Set 6 | altamira
# Processing Record 45 of Set 6 | acapulco
# Processing Record 46 of Set 6 | kokstad
# Processing Record 47 of Set 6 | taltal
# Processing Record 48 of Set 6 | nagapattinam
# Processing Record 49 of Set 6 | puerto leguizamo
# Processing Record 0 of Set 7 | krasnoselkup
# Processing Record 1 of Set 7 | phalodi
# Processing Record 2 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 7 | cohoes
# Processing Record 4 of Set 7 | buraydah
# Processing Record 5 of Set 7 | guerrero negro
# Processing Record 6 of Set 7 | bandarbeyla
# Processing Record 7 of Set 7 | samana
# Processing Record 8 of Set 7 | ostrovnoy
# Processing Record 9 of Set 7 | rucheng
# Processing Record 10 of Set 7 | shelburne
# Processing Record 11 of Set 7 | mahon
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | roald
# Processing Record 14 of Set 7 | aporawan
# City not found. Skipping...
# Processing Record 15 of Set 7 | hofn
# Processing Record 16 of Set 7 | kariba
# Processing Record 17 of Set 7 | terney
# Processing Record 18 of Set 7 | urucara
# Processing Record 19 of Set 7 | gizo
# Processing Record 20 of Set 7 | coruripe
# Processing Record 21 of Set 7 | saint george
# Processing Record 22 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 7 | xuddur
# Processing Record 24 of Set 7 | hithadhoo
# Processing Record 25 of Set 7 | havre
# Processing Record 26 of Set 7 | nioro
# Processing Record 27 of Set 7 | penha
# Processing Record 28 of Set 7 | kattivakkam
# Processing Record 29 of Set 7 | basco
# Processing Record 30 of Set 7 | woodward
# Processing Record 31 of Set 7 | hirara
# Processing Record 32 of Set 7 | porto real do colegio
# Processing Record 33 of Set 7 | east london
# Processing Record 34 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 35 of Set 7 | natal
# Processing Record 36 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 37 of Set
of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 19 of Set 9 | vlakhopoulon
# Processing Record 20 of Set 9 | ilhabela
# Processing Record 21 of Set 9 | uddevalla
# Processing Record 22 of Set 9 | acarau
# Processing Record 23 of Set 9 | chapleau
# Processing Record 24 of Set 9 | mogadishu
# Processing Record 25 of Set 9 | kiunga
# Processing Record 26 of Set 9 | kargat
# Processing Record 27 of Set 9 | caravelas
# Processing Record 28 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 9 | the valley
# Processing Record 30 of Set 9 | bogorodskoye
# Processing Record 31 of Set 9 | hami
# Processing Record 32 of Set 9 | malatya
# Processing Record 33 of Set 9 | cockburn town
# Processing Record 34 of Set 9 | jackson
# Processing Record 35 of Set 9 | dawson creek
# Processing Record 36 of Set 9 | lata
# Processing Record 37 of Set 9 | egvekinot
# Processing Record 38 of Set 9 | riverton
# Processing Record 39 of Set 9 | susaki
# Processing Record 40 of Set 9 | port shepstone
# Processing Record 41 of Set 9 | ronne
# Processing Record 42 of Set 9 | guangyuan
# Processing Record 43 of Set 9 | shimoda
# Processing Record 44 of Set 9 | baglung
# Processing Record 45 of Set 9 | rapid valley
# Processing Record 46 of Set 9 | ulaangom
# Processing Record 47 of Set 9 | ahuimanu
# Processing Record 48 of Set 9 | dourados
# Processing Record 49 of Set 9 | chapais
# Processing Record 0 of Set 10 | dumas
# Processing Record 1 of Set 10 | casablanca
# Processing Record 2 of Set 10 | kotelnikovo
# Processing Record 3 of Set 10 | boende
# Processing Record 4 of Set 10 | praia
# Processing Record 5 of Set 10 | ukiah
# Processing Record 6 of Set 10 | consuegra
# Processing Record 7 of Set 10 | zhovti vody
# Processing Record 8 of Set 10 | kirkuk
# Processing Record 9 of Set 10 | shenjiamen
# Processing Record 10 of Set 10 | sidney
# Processing Record 11 of Set 10 | kenai
# Processing Record 12 of Set 10 | lazo
# Processing Record 13 of Set 10 | hay river
# Processing Record 14 of Set 10 | buala
# Processing Record 15 of Set 10 | taquari
# Processing Record 16 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 10 | ulladulla
# Processing Record 18 of Set 10 | lashio
# Processing Record 19 of Set 10 | ayni
# Processing Record 20 of Set 10 | dicabisagan
# Processing Record 21 of Set 10 | bathsheba
# Processing Record 22 of Set 10 | kraste
# City not found. Skipping...
# Processing Record 23 of Set 10 | zabid
# Processing Record 24 of Set 10 | half moon bay
# Processing Record 25 of Set 10 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 26 of Set 10 | benghazi
# Processing Record 27 of Set 10 | bograd
# Processing Record 28 of Set 10 | havelock
# Processing Record 29 of Set 10 | nanortalik
# Processing Record 30 of Set 10 | pemangkat
# Processing Record 31 of Set 10 | libertador general san martin
# Processing Record 32 of Set 10 | portland
# Processing Record 33 of Set 10 | goundam
# Processing Record 34 of Set 10 | erdenet
# Processing Record 35 of Set 10 | pathein
# Processing Record 36 of Set 10 | bengkulu
# Processing Record 37 of Set 10 | tutoia
# Processing Record 38 of Set 10 | talaya
# Processing Record 39 of Set 10 | kracheh
# City not found. Skipping...
# Processing Record 40 of Set 10 | hervey bay
# Processing Record 41 of Set 10 | esperance
# Processing Record 42 of Set 10 | terra santa
# Processing Record 43 of Set 10 | alvorada
# Processing Record 44 of Set 10 | pacific grove
# Processing Record 45 of Set 10 | bose
# Processing Record 46 of Set 10 | raga
# Processing Record 47 of Set 10 | victoria
# Processing Record 48 of Set 10 | storforshei
# Processing Record 49 of Set 10 | makakilo city
# Processing Record 0 of Set 11 | okato
# Processing Record 1 of Set 11 | timra
# Processing Record 2 of Set 11 | maragogi
# Processing Record 3 of Set 11 | sabla
# Processing Record 4 of Set 11 | agadir
# Processing Record 5 of Set 11 | sonoita
# Processing Record 6 of Set 11 | sainte-anne-des-monts
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | mericleri
# City not found. Skipping...
# Processing Record 9 of Set 11 | mazurivka
# Processing Record 10 of Set 11 | cayenne
# Processing Record 11 of Set 11 | tarko-sale
# Processing Record 12 of Set 11 | zlate hory
# Processing Record 13 of Set 11 | ternate
# Processing Record 14 of Set 11 | akyab
# Processing Record 15 of Set 11 | halle
# Processing Record 16 of Set 11 | sampit
# Processing Record 17 of Set 11 | pimentel
# Processing Record 18 of Set 11 | wattegama
# Processing Record 19 of Set 11 | piacabucu
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | saldanha
# Processing Record 22 of Set 11 | vidim
# Processing Record 23 of Set 11 | tupik
# Processing Record 24 of Set 11 | pyinmana
# Processing Record 25 of Set 11 | umrala
# Processing Record 26 of Set 11 | sechura
# Processing Record 27 of Set 11 | alofi
# Processing Record 28 of Set 11 | gavle
# Processing Record 29 of Set 11 | takaka
# Processing Record 30 of Set 11 | stornoway
# Processing Record 31 of Set 11 | khorramabad
# Processing Record 32 of Set 11 | moengo
# Processing Record 33 of Set 11 | shetpe
# Processing Record 34 of Set 11 | lima
# Processing Record 35 of Set 11 | ushtobe
# Processing Record 36 of Set 11 | bolshiye saly
# City not found. Skipping...
# Processing Record 37 of Set 11 | yulara
# Processing Record 38 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 11 | bambari
# Processing Record 40 of Set 11 | mafinga
# Processing Record 41 of Set 11 | along
# Processing Record 42 of Set 11 | ziro
# Processing Record 43 of Set 11 | san rafael del sur
# Processing Record 44 of Set 11 | tonota
# Processing Record 45 of Set 11 | requena
# Processing Record 46 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 11 | arroyo
# Processing Record 48 of Set 11 | witrivier
# City not found. Skipping...
# Processing Record 49 of Set 11 | adamantina
# Processing Record 0 of Set 12 | pechora
# Processing Record 1 of Set 12 | merauke
# Processing Record 2 of Set 12 | berlevag
# Processing Record 3 of Set 12 | atar
# Processing Record 4 of Set 12 | sioux lookout
# Processing Record 5 of Set 12 | nimaj
# Processing Record 6 of Set 12 | ichinohe
# Processing Record 7 of Set 12 | college
# Processing Record 8 of Set 12 | harnosand
# Processing Record 9 of Set 12 | pakaur
# Processing Record 10 of Set 12 | pereslavl-zalesskiy
# Processing Record 11 of Set 12 | wana
# Processing Record 12 of Set 12 | thaton
# Processing Record 13 of Set 12 | kupang
# Processing Record 14 of Set 12 | ormara
# Processing Record 15 of Set 12 | simbahan
# Processing Record 16 of Set 12 | vredendal
# Processing Record 17 of Set 12 | tawzar
# City not found. Skipping...
# Processing Record 18 of Set 12 | ponazyrevo
# Processing Record 19 of Set 12 | nolinsk
# Processing Record 20 of Set 12 | gwadar
# Processing Record 21 of Set 12 | santa rosa
# Processing Record 22 of Set 12 | rawson
# Processing Record 23 of Set 12 | waiouru
# Processing Record 24 of Set 12 | nicoya
# Processing Record 25 of Set 12 | luderitz
# Processing Record 26 of Set 12 | palmer
# Processing Record 27 of Set 12 | pinheiro machado
# Processing Record 28 of Set 12 | fort william
# Processing Record 29 of Set 12 | malartic
# Processing Record 30 of Set 12 | vardo
# Processing Record 31 of Set 12 | lulea
# Processing Record 32 of Set 12 | laje
# Processing Record 33 of Set 12 | atambua
# Processing Record 34 of Set 12 | salinas
# Processing Record 35 of Set 12 | matto
# City not found. Skipping...
# Processing Record 36 of Set 12 | artyom
# Processing Record 37 of Set 12 | nyirbogat
# Processing Record 38 of Set 12 | talcahuano
# Processing Record 39 of Set 12 | grimari
# City not found. Skipping...
# Processing Record 40 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 41 of Set 12 | sakakah
# Processing Record 42 of Set 12 | roma
# Processing Record 43 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 12 | gasa
# Processing Record 45 of Set 12 | vytegra
# Processing Record 46 of Set 12 | emba
# Processing Record 47 of Set 12 | nantucket
# Processing Record 48 of Set 12 | necochea
# Processing Record 49 of Set 12 | isangel
# Processing Record 0 of Set 13 | aguilas
# Processing Record 1 of Set 13 | gumdag
# Processing Record 2 of Set 13 | dunedin
# Processing Record 3 of Set 13 | saint-denis
# Processing Record 4 of Set 13 | kikwit
# Processing Record 5 of Set 13 | bucerias
# Processing Record 6 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 13 | kaohsiung
# Processing Record 8 of Set 13 | inhambane
# Processing Record 9 of Set 13 | mezhdurechensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        553 non-null    object
#  1   Lat         553 non-null    float64
#  2   Lng         553 non-null    float64
#  3   Max Temp    553 non-null    float64
#  4   Humidity    553 non-null    int64
#  5   Cloudiness  553 non-null    int64
#  6   Wind Speed  553 non-null    float64
#  7   Country     553 non-null    object
#  8   Date        553 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.0+ KB

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    tasiilaq  65.6145  -37.6368      2.09        93          97        6.39
# 1  sao filipe  14.8961  -24.4956     22.48        76           7        4.21
# 2   cape town -33.9258   18.4232     17.27        66           0        0.51
# 3       airai  -8.9266  125.4092     16.16        93          85        0.80
# 4     rikitea -23.1203 -134.9692     25.30        69          18        5.70
#
#   Country        Date
# 0      GL  1681322708
# 1      CV  1681322709
# 2      ZA  1681322517
# 3      TL  1681322709
# 4      PF  1681322710

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %%
city_data_df['Max Temp'].min()
# Out:
# -29.71

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df['Lat'],
    city_data_df['Max Temp'],
    edgecolors='black'
)

# Incorporate the other graph properties
today_date = str(datetime.now().year)+'-'+str(datetime.now().month)+'-'+str(datetime.now().day)

plt.title(f"City Latitude vs. Max Temperature ({today_date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df['Lat'],
    city_data_df['Humidity'],
    edgecolors='black'
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({today_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df['Lat'],
    city_data_df['Cloudiness'],
    edgecolors='black'
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({today_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df['Lat'],
    city_data_df['Wind Speed'],
    edgecolors='black'
)

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({today_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind speed (m/s)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression(x_values, y_values, annotation_tuple = None):
    # Get regression data
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Generate regression values and line equation
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create plot
    plt.scatter(x_values,y_values)
    
    # Label axes
    if x_values.name == 'Lat':
        plt.xlabel('Latitude')
    else:
        plt.xlabel(x_values.name)
    plt.ylabel(y_values.name)
    
    # Plot the linear regression
    if annotation_tuple == None:
        annotation_tuple = (0,0)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,annotation_tuple,fontsize=15,color="red")
    print(f"The r-squared is: {rvalue**2}")
    plt.show

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    tasiilaq  65.6145  -37.6368      2.09        93          97        6.39
# 1  sao filipe  14.8961  -24.4956     22.48        76           7        4.21
# 5    pochutla  15.7432  -96.4661     32.12        43           1        5.14
# 7    cardston  49.2000 -113.3019      4.08        30          20        4.12
# 8     lerwick  60.1545   -1.1494      8.00        80          93        8.53
#
#   Country        Date
# 0      GL  1681322708
# 1      CV  1681322709
# 5      MX  1681322710
# 7      CA  1681322449
# 8      GB  1681322711

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 2   cape town -33.9258   18.4232     17.27        66           0        0.51
# 3       airai  -8.9266  125.4092     16.16        93          85        0.80
# 4     rikitea -23.1203 -134.9692     25.30        69          18        5.70
# 6     mataura -46.1927  168.8643     11.38        98         100        2.68
# 12     avarua -21.2078 -159.7750     26.03        78          40        3.09
#
#    Country        Date
# 2       ZA  1681322517
# 3       TL  1681322709
# 4       PF  1681322710
# 6       NZ  1681322710
# 12      CK  1681322713

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
create_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
# Out:
# The r-squared is: 0.7188174164626183

# %%
# Linear regression on Southern Hemisphere
create_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], (-25, 7))
# Out:
# The r-squared is: 0.5414057334967274

# %% [markdown]
# **Discussion about the linear relationship:** The linear regressions above show that in the northern hemisphere, as the latitude increases (moves further north) a city's max temperature decreases. In the southern hemisphere, as the latitude decreases (moves further south) a city's max temperature decreases. This intuatively makes sense because we know that temperatures are usually cooler at the Earth's poles.
#
# It's interesting to note that while the relationship between latitude and max temperature are strongly correlated in both hemispheres, the correlation is notably higher in the north compared to the south.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], (48,20))
# Out:
# The r-squared is: 0.10535510644158497

# %%
# Southern Hemisphere
create_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], (-55, 30))
# Out:
# The r-squared is: 0.018050847666026253

# %% [markdown]
# **Discussion about the linear relationship:** The plots above very clearly show that latitude and humidity are not very correlated. We can see that in both cases, as cities move closer to the Equator, the humidity tends to rise. However, the spread of the scatter plot data as well as the r-squared values clearly tell us that latitude explains a near negligable amount of variation in humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], (70,30))
# Out:
# The r-squared is: 0.021521199976257958

# %%
# Southern Hemisphere
create_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], (-55,10))
# Out:
# The r-squared is: 0.02750218622155148

# %% [markdown]
# **Discussion about the linear relationship:** The r-squared values for both these plots show that cloudiness has virtually no correlation with latitude. Both linear regressions have a small positive slope, meaning that as latitude increases, so too does cloudiness. But since the correlations are so low, latitude cannot be used to predict cloudiness in any meaningful way, regardless of hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], (0,14))
# Out:
# The r-squared is: 0.0015440112847342371

# %%
# Southern Hemisphere
create_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], (-20,10))
# Out:
# The r-squared is: 0.09710374164757354

# %% [markdown]
# **Discussion about the linear relationship:** Once again the correlation between latitude and wind speed is very small which tells us that latitude explains virtually none of the variation in wind speed. Both northern and southern hemisphere linear regressions have slopes very close to 0 which indicates that as the latitude changes, the wind speed remains relatively constant.
